-- %%
SELECT * FROM dev.demo.drivers

-- %%
-- DESCRIBE : Give you schema of the Table

describe dev.demo.drivers

-- %%
-- Describe Extended : Give you all information regarding Table

describe extended dev.demo.drivers

-- %%
-- Describe Detail : Give you size and other info regarding Table

describe detail dev.demo.drivers

-- %%
-- Describe History :  Check Table's History

describe history dev.demo.drivers
