# %%
# %run "/Workspace/Users/kaushikaman027@gmail.com/Aman Databricks Training/Day6_Medellian_Architrecture/includes"

# %%
dbutils.widgets.text("catalog","default")
#dbutils.widgets.text("table","default")

catalog=dbutils.widgets.get("catalog")
#table=dbutils.widgets.get("table")

# %%
df=spark.read.csv(f"{input_path}/sales.csv",header=True,inferSchema=True)

df1=add_metadata_col(df)

df1.write.mode("overwrite").saveAsTable(f"{catalog}.bronze.sales")
